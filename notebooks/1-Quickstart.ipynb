# %% [markdown]
# # GraphRAG Quickstart

# %% [markdown]
# ## Prerequisites
# Install 3rd party packages, not part of the Python Standard Library, to run the notebook

# %%
! pip install devtools python-magic requests tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting devtools
#   Downloading devtools-0.12.2-py3-none-any.whl (19 kB)
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 9.2 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from devtools) (2.4.1)
# Requirement already satisfied: pygments>=2.15.0 in /home/vscode/.local/lib/python3.10/site-packages (from devtools) (2.18.0)
# Requirement already satisfied: executing>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from devtools) (2.1.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 15.6 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 14.4 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 kB 17.9 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /home/vscode/.local/lib/python3.10/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)
# Installing collected packages: urllib3, tqdm, python-magic, idna, charset-normalizer, certifi, requests, devtools
# Successfully installed certifi-2024.8.30 charset-normalizer-3.3.2 devtools-0.12.2 idna-3.10 python-magic-0.4.27 requests-2.32.3 tqdm-4.66.5 urllib3-2.2.3

# %%
import getpass
import json
import time
from pathlib import Path

import magic
import requests
from devtools import pprint
from tqdm import tqdm

# %% [markdown]
# ## (REQUIRED) User Configuration
# Set the API subscription key, API base endpoint, and some file directory names that will be referenced later in the notebook.

# %% [markdown]
# #### API subscription key
#
# APIM supports multiple forms of authentication and access control (e.g. managed identity). For this notebook demonstration, we will use a **[subscription key](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions)**. To locate this key, visit the Azure Portal. The subscription key can be found under `<my_resource_group> --> <API Management service> --> <APIs> --> <Subscriptions> --> <Built-in all-access subscription> Primary Key`. For multiple API users, individual subscription keys can be generated.

# %%
ocp_apim_subscription_key = getpass.getpass(
    "Enter the subscription key to the GraphRag APIM:"
)

"""
"Ocp-Apim-Subscription-Key": 
    This is a custom HTTP header used by Azure API Management service (APIM) to 
    authenticate API requests. The value for this key should be set to the subscription 
    key provided by the Azure APIM instance in your GraphRAG resource group.
"""
headers = {"Ocp-Apim-Subscription-Key": ocp_apim_subscription_key}

# %% [markdown]
# #### Setup directories and API endpoint
#
# For demonstration purposes, please use the provided `get-wiki-articles.py` script to download a small set of wikipedia articles or provide your own data (graphrag requires txt files to be utf-8 encoded).

# %%
"""
These parameters must be defined by the notebook user:

- file_directory: a local directory of text files. The file structure should be flat,
                  with no nested directories. (i.e. file_directory/file1.txt, file_directory/file2.txt, etc.)
- storage_name:   a unique name to identify a blob storage container in Azure where files
                  from `file_directory` will be uploaded.
- index_name:     a unique name to identify a single graphrag knowledge graph index.
                  Note: Multiple indexes may be created from the same `storage_name` blob storage container.
- endpoint:       the base/endpoint URL for the GraphRAG API (this is the Gateway URL found in the APIM resource).
"""

file_directory = 'testdata' 
storage_name = "blob_wiki"
index_name = "index_wiki"
endpoint = "https://apim-nm3tdxr5bosd2.azure-api.net"

# %%
assert (
    file_directory != "" and storage_name != "" and index_name != "" and endpoint != ""
)

# %% [markdown]
# ## Upload Files
#
# For a demonstration of how to index data in graphrag, we first need to ingest a few files into graphrag.

# %%
def upload_files(
    file_directory: str,
    storage_name: str,
    batch_size: int = 100,
    overwrite: bool = True,
    max_retries: int = 5,
) -> requests.Response | list[Path]:
    """
    Upload files to a blob storage container.

    Args:
    file_directory - a local directory of .txt files to upload. All files must have utf-8 encoding.
    storage_name - a unique name for the Azure storage blob container.
    batch_size - the number of files to upload in a single batch.
    overwrite - whether or not to overwrite files if they already exist in the storage blob container.
    max_retries - the maximum number of times to retry uploading a batch of files if the API is busy.

    NOTE: Uploading files may sometimes fail if the blob container was recently deleted
    (i.e. a few seconds before. The solution "in practice" is to sleep a few seconds and try again.
    """
    url = endpoint + "/data"

    def upload_batch(
        files: list, storage_name: str, overwrite: bool, max_retries: int
    ) -> requests.Response:
        for _ in range(max_retries):
            response = requests.post(
                url=url,
                files=files,
                params={"storage_name": storage_name, "overwrite": overwrite},
                headers=headers,
            )
            # API may be busy, retry
            if response.status_code == 500:
                print("API busy. Sleeping and will try again.")
                time.sleep(10)
                continue
            return response
        return response

    batch_files = []
    accepted_file_types = ["text/plain"]
    filepaths = list(Path(file_directory).iterdir())
    for file in tqdm(filepaths):
        # validate that file is a file, has acceptable file type, has a .txt extension, and has utf-8 encoding
        if (
            not file.is_file()
            or file.suffix != ".txt"
            or magic.from_file(str(file), mime=True) not in accepted_file_types
        ):
            print(f"Skipping invalid file: {file}")
            continue
        # open and decode file as utf-8, ignore bad characters
        batch_files.append(
            ("files", open(file=file, mode="r", encoding="utf-8", errors="ignore"))
        )
        # upload batch of files
        if len(batch_files) == batch_size:
            response = upload_batch(batch_files, storage_name, overwrite, max_retries)
            # if response is not ok, return early
            if not response.ok:
                return response
            batch_files.clear()
    # upload remaining files
    if len(batch_files) > 0:
        response = upload_batch(batch_files, storage_name, overwrite, max_retries)
    return response


response = upload_files(
    file_directory=file_directory,
    storage_name=storage_name,
    batch_size=100,
    overwrite=True,
)
if not response.ok:
    print(response.text)
else:
    print(response)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 23.31it/s]
# <Response [200]>

# %% [markdown]
# ## Build an Index
#
# After data files have been uploaded, we can construct a knowledge graph by building a search index.

# %%
def build_index(
    storage_name: str,
    index_name: str,
) -> requests.Response:
    """Create a search index.
    This function kicks off a job that builds a knowledge graph index from files located in a blob storage container.
    """
    url = endpoint + "/index"
    request = {"storage_name": storage_name, "index_name": index_name}
    return requests.post(url, params=request, headers=headers)


response = build_index(storage_name=storage_name, index_name=index_name)
print(response)
if response.ok:
    print(response.text)
else:
    print(f"Failed to submit job.\nStatus: {response.text}")
# Out:
# <Response [202]>
# {"detail":"Index 'index_wiki' already exists and has not finished building."}

# %% [markdown]
# ### Check status of an indexing job
#
# Please wait for your index to reach 100 percent completion before continuing on to the next section (running queries). You may rerun the next cell multiple times to monitor status. Note: the indexing speed of graphrag is directly correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
def index_status(index_name: str) -> requests.Response:
    url = endpoint + f"/index/status/{index_name}"
    return requests.get(url, headers=headers)


response = index_status(index_name)
pprint(response.json())
# Out:
# {
#     'status_code': 200,
#     'index_name': 'index_wiki',
#     'storage_name': 'blob_wiki',
#     'status': 'scheduled',
#     'percent_complete': 0.0,
#     'progress': '',
# }

# %%
pprint(response.json())
# Out:
# {
#     'status_code': 200,
#     'index_name': 'index_wiki',
#     'storage_name': 'blob_wiki',
#     'status': 'scheduled',
#     'percent_complete': 0.0,
#     'progress': '',
# }

# %% [markdown]
# ## Query
#
# Once an indexing job is complete, the knowledge graph is ready to query. Two types of queries (global and local) are currently supported. We encourage you to try both and experience the difference in responses. Note that query response time is also correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
# a helper function to parse out the result from a query response
def parse_query_response(
    response: requests.Response, return_context_data: bool = False
) -> requests.Response | dict[list[dict]]:
    """
    Print response['result'] value and return context data.
    """
    if response.ok:
        print(json.loads(response.text)["result"])
        if return_context_data:
            return json.loads(response.text)["context_data"]
        return response
    else:
        print(response.reason)
        print(response.content)
        return response

# %% [markdown]
# ### Global Query
#
# Global queries are resource-intensive, but provide good responses to questions that require an understanding of the dataset as a whole.

# %%
# %%time


def global_search(index_name: str | list[str], query: str) -> requests.Response:
    """Run a global query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/global"
    request = {"index_name": index_name, "query": query}
    return requests.post(url, json=request, headers=headers)


# perform a global query
global_response = global_search(
    index_name=index_name, query="Summarize the main topics found in this data"
)
global_response_data = parse_query_response(global_response, return_context_data=True)
global_response_data
# Out:
# ### Overview of Main Topics in the Dataset
#
# The dataset provides a comprehensive overview of various aspects of U.S. cities and states, focusing on their economic, cultural, environmental, and technological dimensions. Here's a breakdown of the main topics covered:
#
# #### Geographical and Cultural Insights
# The dataset includes detailed geographical and cultural overviews of states like Alaska and New York, emphasizing the unique attributes of regions such as Silicon Valley, Washington, D.C., and Southeast Alaska. These insights cover everything from the historical significance of cities like Anchorage and Fairbanks to the cultural importance of regions like Southeast Alaska [Data: Reports (59, 62, 43, 82, 68, 13, +more)].
#
# #### Environmental and Ecological Significance
# Significant emphasis is placed on the environmental and ecological aspects of various regions. This includes discussions on the conservation efforts and challenges in places like the Sierra Nevada and the ecosystems around rivers such as the Potomac, Anacostia, and Columbia. The interplay between natural resources and community development is highlighted, showing how these elements contribute to local water systems and urban development [Data: Reports (43, 97, 89, 58, 50, 54, 87, 49, +more)].
#
# #### Economic and Technological Development
# The dataset explores the economic impacts and technological advancements in regions known for their tech industries, such as Silicon Valley and Tech Valley. It discusses the roles of major companies like Microsoft and academic institutions in driving technological innovation and regional development. The influence of tech giants and the collaboration between universities and tech companies are detailed, showing their impact on local and global technology trends [Data: Reports (82, 83, 91, 90)].
#
# #### Historical Events and Figures
# The impact of historical events and figures on regional development is another critical area covered. This includes the founding of Washington, D.C., the abolition of slavery there, and the advocacy for Alaska's statehood. The dataset also touches on the Dutch colony of New Netherland and the Erie Canal's influence on New York State's development [Data: Reports (42, 44, 93, 71, 47, 53, 19)].
#
# #### Infrastructure and Strategic Importance
# Infrastructure developments and the strategic importance of locations like the National Mall in Washington D.C. are discussed. The roles of transportation systems in Alaska, such as Alaska Airlines and the Alaska Highway, in connecting remote areas and supporting local economies are explored. Additionally, the dataset covers the Smithsonian Institution's role as a cultural and educational cornerstone [Data: Reports (68, 9, 64, 49, 100, 98)].
#
# ### Conclusion
# The dataset provides a rich tapestry of information that paints a detailed picture of the multifaceted nature of U.S. regions. From environmental conservation to technological innovation and historical significance, the data encapsulates the diverse factors that contribute to the identity and development of various American locales.
# CPU times: user 17.6 ms, sys: 9.91 ms, total: 27.5 ms
# Wall time: 33.3 s
# {'reports': [{'id': '30',
#    'title': "California's Influence: Economic, Environmental, and Judicial Insights",
#    'occurrence weight': 1.0,
#    'content': "# California's Influence: Economic, Environmental, and Judicial Insights\n\nCalifornia, as a major U.S. state, significantly influences the economy, environment, and judicial system. Its capital, Sacramento, plays a pivotal role in governance and policy-making. The state's economic prowess, technological and cultural contributions, environmental management, and agricultural dominance are key aspects. The relationships between entities like the Supreme Court of California and the Judicial Council highlight the state's structured judicial influence.\n\n## California's Economic Impact\n\nCalifornia's economy, being the largest of any U.S. state, significantly impacts global trade and economic policies. The state's ports, especially the Port of Los Angeles, are crucial in handling a major portion of U.S. imports, emphasizing its role in international trade. This economic might positions California as a global economic leader, influencing global economic dynamics and policies [Data: Claims (2, 75, 76, 77, 78); Relationships (62, 63)].\n\n## Technological and Cultural Dominance\n\nCalifornia is recognized globally for its contributions through Silicon Valley and Hollywood, marking it as a major center for the tech and entertainment industries. This influence extends to shaping global digital and media landscapes, highlighting its role in cultural and technological advancements worldwide [Data: Claims (4, 30); Relationships (70)].\n\n## Proactive Environmental Management\n\nFacing environmental challenges like droughts and wildfires, California has implemented large-scale projects and innovative practices such as the California Aqueduct and controlled burns. These efforts are vital for addressing climate change impacts and natural disasters, reflecting California's proactive approach to environmental management [Data: Claims (5, 6, 34, 36, 46, 94)].\n\n## Historical and Social Developments\n\nCalifornia's history, including the Gold Rush and the treatment of indigenous populations, has significantly shaped its demographic and cultural landscape. Recent efforts towards acknowledging historical injustices and promoting indigenous rights demonstrate the state's evolving social policies [Data: Claims (1, 22, 38)].\n\n## Agricultural Dominance and Global Food Supply\n\nAs the leading agricultural state in the U.S., California's production of dairy, almonds, and grapes not only supports its economy but also contributes significantly to the national and global food markets. This sector's impact highlights the state's crucial role in global food security [Data: Claims (3, 82)].\n\n## Judicial Influence and Governance\n\nThe Supreme Court of California, as the highest court in the state, along with the Judicial Council of California, plays a significant role in the administration of the state's court system. This structured relationship enhances the judicial influence over state-wide decisions and actions, impacting governance and policy-making at various levels [Data: Entities (201, 204); Relationships (78, 204)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '30'},
#   {'id': '92',
#    'title': 'New York City: A Global Hub of Diversity, Commerce, and Culture',
#    'occurrence weight': 0.5789473684210527,
#    'content': "# New York City: A Global Hub of Diversity, Commerce, and Culture\n\nNew York City, as a major urban area, serves as a central hub for commerce, culture, and immigration. It is intricately connected with various global entities and historical events, significantly impacting both the local and international landscape. The city's relationships with countries like China and India highlight its role as a melting pot of cultures and a significant destination for immigrants. Additionally, its historical significance and current status as a financial and technological epicenter underscore its global influence.\n\n## New York City as a pivotal global city\n\nNew York City is recognized globally for its significant influence in finance, technology, and culture. Hosting entities like the United Nations and major stock exchanges such as NASDAQ and the New York Stock Exchange, the city plays a crucial role in international diplomacy and global markets. The presence of these institutions not only boosts the city's global profile but also its economic vitality [Data: Entities (835, 983, 982); Relationships (783, 781)].\n\n## Significant immigrant populations from China and India\n\nThe city's demographic landscape is heavily shaped by its immigrant populations, with notable communities from China and India. These communities contribute to the city's cultural diversity and economic activities, particularly in sectors like technology and commerce. The relationships between New York City and these countries are strengthened by ongoing immigration, which supports New York's status as a cosmopolitan hub [Data: Entities (959, 960); Relationships (772, 773)].\n\n## Historical significance during the American Civil War\n\nNew York City's role during the American Civil War as a provider of financial support and resources was crucial for the Union. This historical involvement has shaped much of the city's historical narrative and its development as a financial center. The city's strategic decisions during this period have had long-lasting effects on its socio-economic structure [Data: Entities (63); Relationships (150)].\n\n## Technological innovation and investment\n\nThe city's technology sector, especially in artificial intelligence, has seen significant growth, underscored by substantial venture capital investments. Initiatives to regulate and foster technological advancements demonstrate the city's commitment to maintaining a leading position in the global tech landscape [Data: Claims (445, 446)].\n\n## Cultural and historical landmarks\n\nNew York City is home to numerous cultural and historical landmarks, including the Stonewall National Monument and the Theodore Roosevelt Birthplace. These sites not only attract tourists but also serve as important symbols of the city's diverse cultural history and its role in national movements such as LGBTQ rights and presidential history [Data: Entities (944, 945); Relationships (763, 764)].",
#    'rank': 9.5,
#    'index_name': 'index_wiki',
#    'index_id': '92'},
#   {'id': '42',
#    'title': "Washington, D.C.: A Comprehensive Overview of the Capital's Community and Infrastructure",
#    'occurrence weight': 0.5789473684210527,
#    'content': "# Washington, D.C.: A Comprehensive Overview of the Capital's Community and Infrastructure\n\nWashington, D.C. serves as the capital of the United States and is a pivotal area for governmental, cultural, and economic activities. It is characterized by significant landmarks, diverse neighborhoods, and is the center for numerous national and international organizations. The community's structure is deeply intertwined with its historical, political, and social fabric, impacting both local and global affairs.\n\n## Significant Urban Development and Architectural Influence\n\nWashington, D.C. has undergone substantial urban development and renewal, influenced by movements such as the City Beautiful Movement and significant architectural developments. These efforts have shaped the city's layout and skyline, preserving historical designs while accommodating modern needs. The city's architecture and urban planning are crucial in understanding its functionality and aesthetic appeal [Data: Claims (212, 216); Relationships (402)].\n\n## Center for Political and Judicial Power\n\nAs the seat of the U.S. federal government, Washington, D.C. houses major governmental buildings like the White House and the U.S. Capitol. It is also home to the Supreme Court of the United States, making it a central location for major legal and political decisions that affect the entire nation [Data: Entities (418, 461, 598); Relationships (387, 406, 427)].\n\n## Cultural and Historical Significance\n\nWashington, D.C. is notable for its rich cultural and historical heritage, hosting landmarks such as the Lincoln Memorial and the Vietnam Veterans Memorial. It also has a vibrant music scene with historical jazz locations like U Street and the Lincoln Theatre. These cultural elements play a significant role in the city's identity and attract millions of visitors annually [Data: Entities (462, 518); Relationships (407, 416, 418)].\n\n## Economic and Demographic Dynamics\n\nThe city's economy is robust, with a high GDP per capita and significant contributions from sectors like finance, education, and public administration. Washington, D.C. also exhibits complex demographic dynamics, including challenges related to gentrification and shifts in racial composition. These factors are crucial for understanding the city's social structure and economic strategies [Data: Claims (229, 230, 222)].\n\n## Educational and Health Infrastructure\n\nWashington, D.C. has a high rate of educational attainment and health insurance coverage, reflecting its focus on human capital development. However, it faces challenges in its public education system and has a significant rate of HIV/AIDS, which are critical areas for public health and education policy [Data: Claims (223, 224, 226, 227, 279)].\n\n## Diplomatic Hub and International Relations\n\nThe city's status as a diplomatic hub is underscored by the presence of numerous foreign missions and international organizations like the World Bank and the International Monetary Fund. This makes Washington, D.C. a key player in international relations and global policy-making, influencing worldwide economic and political strategies [Data: Entities (421, 420); Relationships (391, 389)].",
#    'rank': 9.5,
#    'index_name': 'index_wiki',
#    'index_id': '42'},
#   {'id': '59',
#    'title': 'Anchorage and Fairbanks: Cultural and Geological Insights of Alaska',
#    'occurrence weight': 0.47368421052631576,
#    'content': "# Anchorage and Fairbanks: Cultural and Geological Insights of Alaska\n\nThis report explores the interconnectedness of Anchorage and Fairbanks, two major cities in Alaska, along with significant entities such as the Islamic Community Center of Anchorage and the Engineering and Geological Evaluation Group. It highlights the cultural, geological, and infrastructural aspects that define these cities and their impact on the region.\n\n## Anchorage as a central hub in Alaska\n\nAnchorage, being the largest city in Alaska, plays a pivotal role as a cultural and economic hub. It is connected to various significant events and entities, including the Islamic Community Center and the Engineering and Geological Evaluation Group. The city's infrastructure and population were heavily impacted by the 1964 Good Friday earthquake, which still influences its developmental policies and emergency preparedness strategies today [Data: Entities (248), Claims (124, 134); Relationships (302, 303, +more)].\n\n## Fairbanks' unique position in Interior Alaska\n\nFairbanks serves as the major urban center in Interior Alaska, known for its extreme climate and cultural vibrancy. It acts as a gateway to the wilderness of Alaska and hosts several cultural events, contributing significantly to the region's diversity and economic activities. The city's connectivity with Anchorage through the Alaska Railroad highlights its importance in regional transportation [Data: Entities (310); Relationships (248, 350)].\n\n## Significance of the Islamic Community Center of Anchorage\n\nThe Islamic Community Center of Anchorage is notable for constructing the first mosque in Alaska, marking a significant development in the religious and cultural landscape of the state. This entity not only represents religious diversity but also contributes to the social fabric of Anchorage [Data: Entities (338); Claims (155); Relationships (308)].\n\n## Impact of the Good Friday Earthquake\n\nThe Good Friday earthquake in 1964 was a defining moment for Anchorage and the surrounding areas. It led to the formation of the Engineering and Geological Evaluation Group, which played a crucial role in assessing and mitigating earthquake damage. This event has had a long-lasting impact on the city's infrastructure and development policies [Data: Entities (273, 277); Claims (123); Relationships (302, 337, 338)].\n\n## Cultural and geological interconnections\n\nThe relationships between Anchorage, Fairbanks, and various entities like the Islamic Community Center and the Engineering and Geological Evaluation Group illustrate the interconnected nature of cultural and geological aspects in Alaska. These connections underscore the complex dynamics that influence regional development and emergency response strategies [Data: Relationships (218, 248, 262, 303, 310)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '59'},
#   {'id': '62',
#    'title': 'Cultural and Historical Significance of Southeast Alaska',
#    'occurrence weight': 0.3684210526315789,
#    'content': "# Cultural and Historical Significance of Southeast Alaska\n\nThis report explores the interconnectedness of key cities and events in Southeast Alaska, focusing on Juneau, Sitka, and Ketchikan, and their roles in the region's cultural and historical narratives. These cities are linked through various relationships that highlight their significance in Alaska's statehood and cultural heritage.\n\n## Juneau as the capital and cultural hub\n\nJuneau, the capital city of Alaska, plays a central role in the state's administration and cultural identity. It is uniquely positioned, being accessible only by ferry or flight, which adds to its distinctiveness. The city's high precipitation levels and historical buildings are notable, and it was a key location during the Alaska statehood movement [Data: Entities (255); Relationships (217, 313, 314, 315)].\n\n## Sitka's historical significance\n\nSitka holds a special place in Alaska's history as the site where the formal transfer of Alaska from Russia to the United States took place, an event commemorated annually as Alaska Day. The city is also known for its cultural events like the Sitka Whale Fest, which celebrate its rich marine life [Data: Entities (259); Relationships (288, 318, 319)].\n\n## Ketchikan's cultural festivities\n\nKetchikan, known for its extreme wet climate, is celebrated for its local festivals such as the Blueberry Festival and the Alaska Hummingbird Festival. These events highlight the city's vibrant local culture and its connection to the natural environment of Southeast Alaska [Data: Entities (313); Relationships (241, 349)].\n\n## Southeast Alaska as a cultural region\n\nSoutheast Alaska, encompassing Juneau, Sitka, and Ketchikan, is a region rich in cultural and historical significance. It serves as a hub for various cultural events and historical commemorations that are integral to understanding Alaska's identity [Data: Entities (305); Relationships (314, 319, 349)].\n\n## Alaska Day's role in regional identity\n\nAlaska Day is a pivotal event in the region, marking the transfer of Alaska from Russia to the U.S. Celebrated particularly in Sitka, this event not only underscores Sitka's historical importance but also serves as a symbol of Alaskan identity and heritage [Data: Entities (260); Relationships (318)].",
#    'rank': 6.5,
#    'index_name': 'index_wiki',
#    'index_id': '62'},
#   {'id': '84',
#    'title': 'San Francisco and Its Historical Roots',
#    'occurrence weight': 0.2631578947368421,
#    'content': "# San Francisco and Its Historical Roots\n\nSan Francisco, a major city in California, is deeply connected to its historical roots, originating from Mission San Francisco de Asís. The city is part of the larger San Francisco Bay Area and closely linked with Silicon Valley, reflecting its significant cultural and technological influence.\n\n## San Francisco's Historical Significance\n\nSan Francisco, known for its dense population and cultural significance, originated from Mission San Francisco de Asís. This historical connection underscores the city's deep cultural roots and its evolution from a mission into a major urban center. The city's growth from these humble beginnings to a technological powerhouse illustrates a significant transformation influenced by various historical events [Data: Entities (28, 31); Relationships (136)].\n\n## Technological Hub within the Bay Area\n\nSan Francisco is a pivotal part of the San Francisco Bay Area and closely associated with Silicon Valley. This relationship highlights the city's role as a central hub in the global technology industry. The proximity and interactions with Silicon Valley enhance San Francisco's position as a leader in innovation and technological development, impacting global technology trends and economic dynamics [Data: Entities (28); Relationships (137)].\n\n## San Francisco's Progressive Policies\n\nSan Francisco's adoption of sanctuary policies reflects its progressive political stance, which has implications for its social and political environment. These policies are indicative of the city's commitment to certain social values and its influence on national and potentially international discussions regarding immigration and civil rights [Data: Entities (28)].\n\n## Cultural and Economic Influence\n\nAs the most densely populated city in California and a major cultural center, San Francisco exerts substantial influence over regional and national cultural trends. The city's economic activities, driven by its technological and cultural sectors, contribute significantly to its stature and impact on both a national and global scale [Data: Entities (28)].\n\n## Connection to the State of California\n\nSan Francisco's role as a major city within California is crucial. It not only serves as a cultural and economic hub but also influences state policies and development strategies. The city's integration within the state's framework is essential for understanding its regional importance and the mutual influences between the city and state [Data: Relationships (16)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '84'},
#   {'id': '96',
#    'title': 'Central Valley and Sacramento-San Joaquin River Delta',
#    'occurrence weight': 0.2631578947368421,
#    'content': "# Central Valley and Sacramento-San Joaquin River Delta\n\nThis community encompasses a significant agricultural and ecological network in California, centered around the Central Valley and extending through the Sacramento-San Joaquin River Delta to the San Francisco Bay. Key entities include the Central Valley, San Joaquin River, Sacramento-San Joaquin River Delta, and San Francisco Bay, each playing a crucial role in California's water system and agricultural output.\n\n## Central Valley's pivotal role in California's agriculture\n\nThe Central Valley is a major agricultural hub in California, known for its extensive production that significantly contributes to the state's economy. It is drained by both the Sacramento and San Joaquin rivers, making it a vital area for water distribution and agricultural activities. The valley's productivity and economic contributions are essential for understanding its impact on food supply and economic stability in the region [Data: Entities (10); Relationships (9, 115, 116)].\n\n## San Joaquin River's ecological and hydrological significance\n\nThe San Joaquin River, named by Gabriel Moraga, is fed primarily by snowmelt from the Sierra Nevada and plays a crucial role in draining the southern half of the Central Valley. Its flow into the Sacramento-San Joaquin River Delta is vital for the region's water system and ecology, impacting water quality and availability across a broad area [Data: Entities (36); Relationships (114, 131, 141, 116)].\n\n## Importance of the Sacramento-San Joaquin River Delta\n\nThe Sacramento-San Joaquin River Delta, formed by the confluence of the Sacramento and San Joaquin rivers, is a critical ecological zone. It serves as a major water distribution hub for California, flowing into the Pacific Ocean through San Francisco Bay. The delta's health and stability are crucial for water quality, supply, and the ecological balance of the surrounding areas [Data: Entities (102); Relationships (141, 142, 184, 185)].\n\n## San Francisco Bay's connection to the delta and ocean\n\nSan Francisco Bay plays a significant role in the community by being the outlet through which the Sacramento-San Joaquin River Delta flows into the Pacific Ocean. This connection is essential for managing water flows and ecological health, influencing both local and regional environments. The bay's role in this hydrological network underscores its importance in the broader ecological system of California [Data: Entities (104); Relationships (185)].\n\n## Interconnectedness and environmental impact\n\nThe interconnectedness of these entities highlights the complex environmental and agricultural systems in California. The Central Valley's dependency on the rivers for irrigation, the rivers' ecological roles, and the delta's function in water distribution and ecological balance all contribute to a highly interconnected system with significant environmental impacts. Understanding these relationships is key to managing California's natural resources effectively [Data: Relationships (9, 114, 115, 116, 141, 142, 184, 185)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '96'},
#   {'id': '44',
#    'title': 'Founding and Design of Washington, D.C.',
#    'occurrence weight': 0.21052631578947367,
#    'content': "# Founding and Design of Washington, D.C.\n\nThis report explores the historical community centered around the founding and design of Washington, D.C., involving key figures such as George Washington, Pierre Charles L'Enfant, and Andrew Ellicott. These individuals played pivotal roles in the establishment and architectural planning of the U.S. capital, influencing its development and legacy.\n\n## George Washington's pivotal role in the establishment of Washington, D.C.\n\nGeorge Washington, as the first President of the United States, had a significant impact on the establishment of the nation's capital. He signed the Residence Act into law, which approved the creation of a national capital on the Potomac River. This decision was crucial in setting the stage for the development of Washington, D.C. [Data: Entities (414), Claims (205)]\n\n## Pierre Charles L'Enfant's architectural vision for Washington, D.C.\n\nPierre Charles L'Enfant was commissioned by George Washington to design the layout of Washington, D.C. His architectural plan, known as the L'Enfant Plan, laid out the streets and important buildings in a grand and systematic way, reflecting his vision for the capital. This design has had a lasting impact on the city's structure and is a testament to L'Enfant's architectural skill. [Data: Entities (417), Relationships (386, 429)]\n\n## Andrew Ellicott's completion of Washington, D.C.'s design\n\nAfter Pierre Charles L'Enfant was dismissed, Andrew Ellicott played a crucial role in completing the design of Washington, D.C. His contributions ensured the continuation and eventual completion of the city's layout, adhering to the initial plans laid out by L'Enfant but with necessary adjustments. This transition marks an important moment in the city's architectural history. [Data: Entities (452), Relationships (431)]\n\n## The naming of Washington state and the capital in honor of George Washington\n\nThe state of Washington and the capital city, Washington, D.C., are both named in honor of George Washington. This naming reflects the profound impact and legacy of Washington's leadership and contributions to the United States. The decision to name significant geographical and political entities after him underscores his historical importance. [Data: Relationships (430, 428)]",
#    'rank': 9.0,
#    'index_name': 'index_wiki',
#    'index_id': '44'},
#   {'id': '95',
#    'title': 'San Francisco Bay Area and San Jose: Historical and Technological Nexus',
#    'occurrence weight': 0.21052631578947367,
#    'content': "# San Francisco Bay Area and San Jose: Historical and Technological Nexus\n\nThe San Francisco Bay Area, a major metropolitan hub in Northern California, is closely linked with San Jose, the first civilian-established city in California. Founded by José Joaquín Moraga, San Jose is an integral part of the Bay Area's rich historical and technological landscape.\n\n## San Francisco Bay Area as a major metropolitan hub\n\nThe San Francisco Bay Area is recognized globally as a central technology hub, contributing significantly to the technological advancements and economic growth in the United States. Its role as one of the most populous urban regions in the country underscores its importance in various sectors including technology, finance, and education. The Bay Area's influence extends beyond its geographical boundaries, impacting national and global markets [Data: Entities (6)].\n\n## Historical significance of San Jose\n\nSan Jose, founded by José Joaquín Moraga, holds a pivotal place in California's history as the first civilian-established city. It was also the host of the first full legislative sessions of California, marking its early political significance. Today, San Jose continues to be a major urban center within the Bay Area, reflecting its ongoing importance in both historical and contemporary contexts [Data: Entities (29); Claims (16); Relationships (133)].\n\n## José Joaquín Moraga's foundational role\n\nJosé Joaquín Moraga, a key historical figure, is credited with founding San Jose, which was a significant development in the establishment of civilian cities in California. His contributions are not only foundational in terms of urban development but also in shaping the early governance structures in the state [Data: Entities (21); Claims (16); Relationships (133)].\n\n## Interconnectedness within the Bay Area\n\nThe relationships between the San Francisco Bay Area, San Jose, and other major cities within the Bay highlight the interconnected nature of this region. These connections facilitate economic, cultural, and technological exchanges that are vital for the sustained growth and innovation in the area [Data: Relationships (5, 109, 110)].\n\n## Technological and economic impact\n\nThe San Francisco Bay Area's status as a technology hub is not only significant for its local economy but also for its global impact. Companies and innovations originating from this area have led to significant technological advancements and economic growth worldwide, reinforcing the Bay Area's position as a critical node in the global economic network [Data: Entities (6)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '95'},
#   {'id': '74',
#    'title': 'Pacific Northwest Regional Community',
#    'occurrence weight': 0.21052631578947367,
#    'content': "# Pacific Northwest Regional Community\n\nThe Pacific Northwest community encompasses several key entities including states and provinces such as Oregon, Washington, British Columbia, Idaho, and occasionally Montana and Alaska. These entities are interconnected through geographical proximity and shared regional characteristics, contributing to economic, environmental, and cultural exchanges across the region.\n\n## Central Role of Washington\n\nWashington is a pivotal entity within the Pacific Northwest, sharing borders with Oregon, Idaho, and the Canadian province of British Columbia. These relationships underscore Washington's central role in regional economic and environmental interactions, which are crucial for understanding the dynamics of the Pacific Northwest [Data: Relationships (531, 311, 101, 532)].\n\n## Inclusion of British Columbia\n\nBritish Columbia, as part of Canada, plays a significant role in the Pacific Northwest by sharing an international border with Washington. This facilitates cross-border trade and cultural exchanges, highlighting the province's integral position in the region [Data: Entities (254), Relationships (311, 312, 224)].\n\n## Oregon's Regional Influence\n\nOregon is another central part of the Pacific Northwest, sharing its southern border with California and its northern border with Washington. These relationships are vital for regional descriptions and emphasize Oregon's role in the Pacific Northwest's economic and environmental frameworks [Data: Entities (1), Relationships (0, 101, 102)].\n\n## Occasional Inclusion of Idaho and Montana\n\nIdaho and Montana are sometimes considered part of the Pacific Northwest. Idaho's proximity to Washington places it within the same geographical region, while Montana's inclusion is based on its location in Western Montana. These occasional inclusions reflect the flexible definitions of the Pacific Northwest [Data: Entities (613, 639), Relationships (532, 624, 625)].\n\n## Extended Reach to Alaska\n\nAlaska is occasionally considered part of the Pacific Northwest, primarily due to its border with British Columbia. This inclusion extends the geographical scope of the Pacific Northwest and highlights the broader regional interactions that transcend typical state and national boundaries [Data: Entities (615), Relationships (298, 224)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '74'},
#   {'id': '56',
#    'title': 'Niagara Falls National Heritage Area and Its Key Entities',
#    'occurrence weight': 0.21052631578947367,
#    'content': "# Niagara Falls National Heritage Area and Its Key Entities\n\nThe Niagara Falls National Heritage Area encompasses a significant geographical and cultural region in New York, including notable entities such as Niagara Falls, Niagara Falls State Park, and Lake Ontario. This area is connected through various relationships that highlight its importance in terms of natural beauty, historical significance, and recreational opportunities.\n\n## Niagara Falls State Park as a pivotal entity\n\nNiagara Falls State Park, established in 1885, is not only the oldest state park in the U.S. but also a cornerstone in the Niagara Falls National Heritage Area. It offers spectacular views of the falls and serves as a major tourist attraction, contributing to both local and state economies. The park's establishment and ongoing protection are crucial for maintaining the natural beauty and historical significance of the area [Data: Entities (927); Claims (422); Relationships (833)].\n\n## Lake Ontario's geographical significance\n\nLake Ontario, bordering the state of New York and Canada, plays a crucial role in the Niagara Falls National Heritage Area by marking its northern boundary. The lake's connection to Niagara Falls via the Niagara River is vital for the area's ecology and hydrology, influencing water levels and environmental conditions that affect both the natural landscape and human activities [Data: Entities (856); Relationships (803)].\n\n## Historical importance of Colonial Niagara Historic District\n\nThe Colonial Niagara Historic District, located within the Niagara Falls National Heritage Area, represents a significant historical component of the region. This district helps preserve the rich history of the area, attracting historians and tourists alike, which in turn supports educational and economic activities [Data: Entities (957); Relationships (841)].\n\n## Integration of communities within the heritage area\n\nCommunities such as Lewiston and Youngstown are integral parts of the Niagara Falls National Heritage Area, contributing to its cultural diversity and local economy. These communities are directly linked to the heritage area, emphasizing the interconnectedness of human settlements and natural landmarks within this region [Data: Entities (956, 955); Relationships (840, 839)].\n\n## Role of Niagara Falls as a dual landmark\n\nNiagara Falls serves a dual role as both a natural wonder and a city within New York. This unique positioning enhances its significance as a key entity in the Niagara Falls National Heritage Area, drawing attention to its cultural, ecological, and recreational importance. The falls are a central feature that connects various aspects of the heritage area, from tourism to conservation efforts [Data: Entities (916); Relationships (831)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '56'},
#   {'id': '41',
#    'title': "Monterey and Thomas O. Larkin: Historical Significance in California's Transition",
#    'occurrence weight': 0.21052631578947367,
#    'content': "# Monterey and Thomas O. Larkin: Historical Significance in California's Transition\n\nThe community focuses on Monterey, a historically significant county in California, and its relationship with Thomas O. Larkin, who played a pivotal role as the U.S. consul during California's transition from Mexican to U.S. control. The entities are interconnected through historical and diplomatic significance, emphasizing the role of Monterey in California's history and Larkin's contributions during a critical period.\n\n## Monterey's historical role as a key location in California\n\nMonterey is not only a county in California but also a site of immense historical value. It was the former capital under Spanish and Mexican rule and played a significant role during the transition of California from Mexican to U.S. control. The presence of the U.S. consulate and the activities conducted there, especially during Thomas O. Larkin's tenure, mark Monterey as a critical location in U.S. history. This historical significance contributes to its impact within the community and beyond, reflecting on its role in shaping regional governance and international relations during a transformative era [Data: Entities (25); Relationships (15)].\n\n## Thomas O. Larkin's diplomatic influence in Monterey\n\nThomas O. Larkin, serving as the U.S. consul in Monterey, was a key figure during the pivotal period when California shifted from Mexican to U.S. control. His diplomatic efforts facilitated this significant change in sovereignty, highlighting his role not only in local governance but also in international diplomacy. The relationship between Monterey and Larkin is crucial for understanding the dynamics of this community, as it underscores the influence of individual actors within historically significant locales. Larkin's actions and decisions during his tenure had lasting impacts on the political landscape of California [Data: Entities (54); Relationships (134)].",
#    'rank': 6.5,
#    'index_name': 'index_wiki',
#    'index_id': '41'},
#   {'id': '61',
#    'title': 'Prudhoe Bay and Trans-Alaska Pipeline System',
#    'occurrence weight': 0.15789473684210525,
#    'content': "# Prudhoe Bay and Trans-Alaska Pipeline System\n\nThe community centers around Prudhoe Bay, a major oil field in Alaska, and the Trans-Alaska Pipeline System which transports oil from Prudhoe Bay across Alaska. This relationship has been pivotal in facilitating the oil boom in Alaska, significantly impacting the state's economy.\n\n## Prudhoe Bay's role as a major oil field\n\nPrudhoe Bay is recognized as the second highest-yielding oil field in the United States and the largest conventional oil field ever discovered in North America. The discovery of massive oil deposits in Prudhoe Bay led to financial solvency and an economic boom in Alaska. This entity's significant contribution to the oil industry marks it as a cornerstone of the community's economic structure [Data: Entities (290), Claims (159)].\n\n## Economic impact of Prudhoe Bay on Alaska\n\nThe economic impact of Prudhoe Bay on Alaska's economy is profound. As a major oil field, it has not only contributed to the state's financial solvency but also influenced broader economic trends and policies within the state. The relationship between Prudhoe Bay and the state of Alaska underscores the field's importance in regional economic planning and sustainability [Data: Entities (290), Relationships (229)].\n\n## Trans-Alaska Pipeline System's role in oil transportation\n\nThe Trans-Alaska Pipeline System plays a critical role in transporting oil from Prudhoe Bay across Alaska. Completed in 1977, this pipeline system facilitated an oil boom by enabling the efficient movement of oil, which is crucial for both local usage and national distribution. The pipeline's operation is vital for maintaining the flow of oil, which has extensive implications for energy security and economic stability [Data: Entities (291), Relationships (345, 346)].\n\n## Interdependency between Prudhoe Bay and the Trans-Alaska Pipeline System\n\nThe interdependency between Prudhoe Bay and the Trans-Alaska Pipeline System is a key aspect of their relationship. Prudhoe Bay's role as a major oil producer is complemented by the pipeline system's capacity to transport this oil to various locations. This symbiotic relationship enhances the operational efficiency and economic output of the oil sector in Alaska, highlighting the strategic importance of maintaining both entities in optimal condition [Data: Relationships (345, 346)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '61'},
#   {'id': '48',
#    'title': 'Tidal Basin Memorials and Monuments Community',
#    'occurrence weight': 0.15789473684210525,
#    'content': "# Tidal Basin Memorials and Monuments Community\n\nThis community encompasses several key memorials and monuments located around the Tidal Basin in Washington, D.C., including the Jefferson Memorial, Franklin Delano Roosevelt Memorial, George Mason Memorial, Martin Luther King Jr. Memorial, and the District of Columbia War Memorial. These entities are interconnected through their geographical proximity to the Tidal Basin, highlighting their collective historical and cultural significance.\n\n## Central Role of the Tidal Basin\n\nThe Tidal Basin plays a pivotal role in this community, serving as the geographical center that links various significant memorials and monuments. It is not only a human-made reservoir but also a celebrated site during the National Cherry Blossom Festival, enhancing its cultural importance. The presence of multiple memorials around the basin underscores its status as a hub of national memory and reflection [Data: Entities (535), Relationships (439, 496, 493, 494, 495)].\n\n## Jefferson Memorial as a Prominent Entity\n\nThe Jefferson Memorial stands out within the community due to its dedication to Thomas Jefferson, a key American Founding Father. Located prominently around the Tidal Basin, it serves as a major tourist attraction and a symbol of American heritage. The memorial's connection to the broader Washington, D.C. area further emphasizes its national significance [Data: Entities (427), Relationships (397, 439)].\n\n## Diverse Historical Representations\n\nThis community is notable for the diversity of historical figures and events it commemorates. From presidents like Franklin Delano Roosevelt to civil rights leaders like Martin Luther King Jr., and even local citizens who served in World War I, the memorials collectively encapsulate a broad spectrum of American history and values. Each memorial's location around the Tidal Basin allows for an integrated historical experience [Data: Entities (545, 546, 547, 548), Relationships (493, 494, 495, 496)].\n\n## Cultural and Educational Impact\n\nThe memorials around the Tidal Basin are not only historical landmarks but also serve educational purposes. They provide insights into different aspects of American history and culture, attracting scholars, students, and tourists. The educational programs and tours offered at these sites help in disseminating knowledge about the figures and events commemorated at each memorial [Data: Entities (427, 545, 546, 547, 548)].\n\n## Preservation and Tourism\n\nPreservation efforts for these memorials are crucial due to their exposure to natural elements and high tourist footfall. The maintenance of these sites ensures that they continue to serve as sources of inspiration and education for future generations. The role of tourism in promoting and sustaining these memorials highlights their economic as well as cultural value to the community and the nation [Data: Entities (427, 535, 545, 546, 547, 548)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '48'},
#   {'id': '69',
#    'title': 'Kodiak and Russian Orthodox Church: Historical and Regional Connectivity in Alaska',
#    'occurrence weight': 0.15789473684210525,
#    'content': "# Kodiak and Russian Orthodox Church: Historical and Regional Connectivity in Alaska\n\nThe community centers around Kodiak, a key regional hub in Southwest Alaska, and the Russian Orthodox Church, the first of its kind in Alaska, established in Kodiak. These entities are linked by historical significance and enhanced connectivity through transportation services provided by Alaska Airlines.\n\n## Kodiak as a Regional Hub\n\nKodiak plays a crucial role as a regional hub in Southwest Alaska, providing essential connectivity to other parts of Alaska and the Aleutian Islands. This is facilitated by scheduled jet service from Anchorage and Fairbanks, which is provided by Alaska Airlines. The town's inclusion in the Alaska Marine Highway system further enhances its accessibility and importance as a transportation node in the region [Data: Entities (339); Relationships (363)].\n\n## Historical Significance of the Russian Orthodox Church\n\nThe Russian Orthodox Church in Kodiak is not only a religious establishment but also a historical landmark. Established in 1795, it marks the beginning of the Russian Orthodox presence in Alaska. This church played a pivotal role in the integration of Russian immigrants into the local society, particularly through intermarriage with Alaskan Natives, which helped in blending cultural and societal norms [Data: Entities (336); Claims (157); Relationships (361)].\n\n## Connectivity between Kodiak and Dutch Harbor\n\nBoth Kodiak and Dutch Harbor are integral parts of Alaska's connectivity framework, accessible by scheduled air service and part of the Alaska Marine Highway system. This shared mode of transportation highlights the interlinked nature of these towns and their importance in regional logistics and mobility [Data: Entities (339, 382); Relationships (362)].",
#    'rank': 4.0,
#    'index_name': 'index_wiki',
#    'index_id': '69'},
#   {'id': '90',
#    'title': 'Cornell University and Technion-Israel Institute of Technology Partnership',
#    'occurrence weight': 0.10526315789473684,
# ...
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '91'},
#   {'id': '29',
#    'title': 'Southern California: Urban Centers and Historical Events',
#    'occurrence weight': 0.10526315789473684,
#    'content': "# Southern California: Urban Centers and Historical Events\n\nSouthern California, a region defined by its significant urban centers such as Los Angeles and San Diego, is linked to several historical events including the 1928 St. Francis Dam flood, the construction of the Los Angeles Aqueducts, and the Rodney King riots. These events and infrastructures have shaped the region's development and societal dynamics.\n\n## Southern California as a pivotal region\n\nSouthern California serves as a major hub in the state, encompassing ten southernmost counties and distinguished urban centers like Los Angeles and San Diego. This region not only supports a massive population but also drives cultural and economic activities that have nationwide implications [Data: Entities (70)].\n\n## Historical significance of the 1928 St. Francis Dam flood\n\nThe 1928 St. Francis Dam flood is one of the deadliest floods in U.S. history, which occurred in Southern California. This catastrophic event highlights the region's vulnerability to infrastructural failures and its impacts on human safety and urban planning [Data: Entities (77); Relationships (154)].\n\n## Importance of the Los Angeles Aqueducts\n\nThe Los Angeles Aqueducts, crucial for water supply to Southern California, particularly Los Angeles, represent a significant engineering feat. These aqueducts have been essential in supporting the urban expansion and population growth of Southern California [Data: Entities (85); Relationships (155)].\n\n## Impact of the Rodney King riots\n\nThe Rodney King riots in 1992 were significant race-related riots that occurred in Los Angeles, a part of Southern California. These riots were pivotal in highlighting racial tensions and the need for police reform within the region [Data: Entities (74); Relationships (153)].\n\n## Southern California as the birthplace of modern car culture\n\nSouthern California is recognized as the birthplace of modern car culture. This claim underscores the region's influence on automotive trends and suburban development, which has shaped transportation behaviors and urban layouts across the United States [Data: Claims (69)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '29'},
#   {'id': '67',
#    'title': 'Iditarod Trail Sled Dog Race and Nome, Alaska',
#    'occurrence weight': 0.10526315789473684,
#    'content': "# Iditarod Trail Sled Dog Race and Nome, Alaska\n\nThe community centers around the Iditarod Trail Sled Dog Race, a significant annual event in Alaska, and Nome, the race's endpoint and a regional hub. The race not only highlights the historical importance of sled dogs in Alaska but also connects various entities including Alaska Airlines and the historical Serum Run.\n\n## Iditarod Trail Sled Dog Race as a cultural and historical event\n\nThe Iditarod Trail Sled Dog Race is an annual event that commemorates the 1925 serum run, which is crucial in the history of Alaska. The race covers a long distance from Anchorage to Nome and is a test of endurance and skill, attracting attention and participants globally. This event not only celebrates historical achievements but also boosts local tourism and economy every March [Data: Entities (365)].\n\n## Nome as a strategic endpoint and regional hub\n\nNome serves as the endpoint for the Iditarod Trail Sled Dog Race, which enhances its significance as a regional hub in Alaska. The city is accessible by jet service from Anchorage and Fairbanks, provided by Alaska Airlines, linking it to major transport networks. This connectivity supports Nome's economic and logistical importance, especially during the race season [Data: Entities (400), Relationships (377)].\n\n## Connection between the Iditarod Race and Nome\n\nThe Iditarod Trail Sled Dog Race culminates in Nome, which is a pivotal moment for the city each year as it becomes the center of national and international attention. The race's conclusion in Nome not only brings economic benefits through tourism but also celebrates the historical and cultural heritage shared by the race and the city [Data: Relationships (368)].\n\n## Historical significance of the Serum Run\n\nThe Serum Run, which also concludes in Nome, follows the historical 1925 serum run route. This event is closely tied to the Iditarod Trail Sled Dog Race and shares its endpoint, reinforcing Nome's historical importance. The Serum Run is a reminder of the critical role sled dogs and their handlers played in saving lives, a narrative that continues to be celebrated through these annual races [Data: Relationships (383)].\n\n## Economic impact of the Iditarod Race on Nome\n\nThe annual Iditarod Trail Sled Dog Race significantly impacts Nome's economy, drawing tourists, media, and dog sledding enthusiasts from around the world. This influx provides a boost to local businesses and increases the demand for services, highlighting the economic interdependence between the event and the city [Data: Entities (365, 400); Relationships (368)].",
#    'rank': 6.5,
#    'index_name': 'index_wiki',
#    'index_id': '67'},
#   {'id': '22',
#    'title': 'Stonewall Riots and National Monument',
#    'occurrence weight': 0.05263157894736842,
#    'content': "# Stonewall Riots and National Monument\n\nThe community centers around the historical Stonewall Riots and the Stonewall National Monument, both located in Greenwich Village. These entities are interconnected through their historical and geographical significance, commemorating a pivotal moment in LGBTQ+ rights.\n\n## Historical significance of the Stonewall Riots\n\nThe Stonewall Riots, a series of spontaneous, violent protests by members of the gay community in 1969, are a pivotal event in the history of LGBTQ+ rights. These riots, which took place at the Stonewall Inn in Greenwich Village, are commemorated by the Stonewall National Monument. The riots' impact on LGBTQ+ rights movements makes them a subject of significant historical importance [Data: Entities (967); Relationships (777)].\n\n## Stonewall National Monument as a commemorative site\n\nThe Stonewall National Monument was established to commemorate the Stonewall Riots. Located in Greenwich Village, the monument serves as a physical reminder of the struggles and achievements of the LGBTQ+ community. It not only marks the site of the riots but also symbolizes the ongoing fight for equality and acceptance. The monument's role in educating and reminding the public of LGBTQ+ history underscores its importance [Data: Entities (968); Relationships (842)].\n\n## Greenwich Village's role in LGBTQ+ history\n\nGreenwich Village is historically significant as the location of the Stonewall Riots and the Stonewall National Monument. This neighborhood has long been a cultural center for the LGBTQ+ community in New York City, fostering an environment of acceptance and resistance. The geographical and cultural significance of Greenwich Village is highlighted by its association with these key historical events [Data: Entities (971); Relationships (843)].",
#    'rank': 8.5,
#    'index_name': 'index_wiki',
#    'index_id': '22'},
#   {'id': '65',
#    'title': 'University of Alaska Fairbanks and Alaska Native Language Center',
#    'occurrence weight': 0.05263157894736842,
#    'content': "# University of Alaska Fairbanks and Alaska Native Language Center\n\nThe community centers around the University of Alaska Fairbanks, which hosts the Alaska Native Language Center. This center is dedicated to the study and preservation of at least 20 Alaskan native languages, highlighting its significant role in cultural preservation within Alaska.\n\n## Significance of the Alaska Native Language Center\n\nThe Alaska Native Language Center (ANLC) is a pivotal institution located at the University of Alaska Fairbanks. It claims to study and preserve at least 20 Alaskan native languages, which are an integral part of the state's cultural heritage. The center's efforts in documenting and revitalizing these languages are crucial as many of them are at risk of extinction. The preservation of language is not only a matter of cultural identity but also of historical significance, making the ANLC's work fundamentally important [Data: Entities (326)].\n\n## Role of the University of Alaska Fairbanks\n\nThe University of Alaska Fairbanks plays a supportive and integral role by hosting the Alaska Native Language Center. This relationship not only emphasizes the university's commitment to cultural and linguistic studies but also enhances its academic reputation. By supporting the ANLC, the university contributes significantly to the preservation of Alaskan native languages and, by extension, to the cultural heritage of Alaska. This collaboration underlines the university's role in academic and cultural preservation initiatives [Data: Entities (327), Relationships (357)].\n\n## Impact of the ANLC on Alaskan Cultural Heritage\n\nThe work of the Alaska Native Language Center extends beyond academic research; it is a vital part of the cultural preservation efforts in Alaska. By studying and claiming the existence of at least 20 native languages, the ANLC helps maintain the linguistic diversity of the region. This not only aids in the education and awareness of these languages but also ensures their continued use in communities, thereby preserving unique cultural identities [Data: Entities (326)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '65'},
#   {'id': '35',
#    'title': 'English Language and Proposition 63 in California',
#    'occurrence weight': 0.05263157894736842,
#    'content': "# English Language and Proposition 63 in California\n\nThis community analysis focuses on the relationship between the English Language and Proposition 63 within the context of California's legal framework. The English Language, as the official language of California, is intricately linked with Proposition 63, which legally enshrined English as the sole official language of the state.\n\n## Legal Status of the English Language in California\n\nThe English Language holds a legally enshrined status as the official language of California. This status is not only a symbolic declaration but also has practical implications on governmental and educational policies across the state. The legal backing significantly affects the linguistic landscape of California, influencing everything from public signage to educational curricula. The relationship between the English Language and the state of California is foundational to understanding the linguistic policies in place [Data: Entities (130), Relationships (44)].\n\n## Impact of Proposition 63 on California's Language Policy\n\nProposition 63 has played a pivotal role in shaping California's language policy by establishing English as the sole official language. This legislative measure has affected various aspects of public life, including education, where it has implications for language instruction and the accessibility of services in languages other than English. The enactment of Proposition 63 has reinforced the predominance of English and has had lasting effects on non-English speaking communities within the state [Data: Entities (139), Relationships (47)].\n\n## Interrelation between English Language and Proposition 63\n\nThe interrelation between the English Language and Proposition 63 is a critical aspect of California's linguistic and legal landscape. Proposition 63 not only supported the status of English but also legally solidified its role, affecting language instruction and usage across the state. This relationship highlights the direct impact of legal frameworks on cultural and societal norms, particularly in multilingual settings like California [Data: Relationships (194)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '35'},
#   {'id': '101',
#    'title': 'Smithsonian American Art Museum and National Portrait Gallery',
#    'occurrence weight': 0.05263157894736842,
#    'content': "# Smithsonian American Art Museum and National Portrait Gallery\n\nThis community encompasses key entities such as the Smithsonian American Art Museum, National Portrait Gallery, Old Patent Office Building, and Renwick Gallery, all of which are interconnected through their historical and cultural significance in Washington, D.C. These entities are part of the larger Smithsonian Institution and are located in proximity to significant landmarks like the White House.\n\n## Smithsonian American Art Museum as a cultural hub\n\nThe Smithsonian American Art Museum is a pivotal entity within this community, housing American art and including the Renwick Gallery. It serves as a cultural hub due to its extensive art collections and exhibitions that attract visitors and scholars alike. The museum's integration with the Renwick Gallery, which focuses on contemporary craft and decorative arts, enhances its appeal and educational value [Data: Entities (525, 527); Relationships (484, 488)].\n\n## National Portrait Gallery's role in American heritage\n\nThe National Portrait Gallery plays a crucial role in preserving American heritage through its extensive collection of portraits of significant Americans. Located in the historic Old Patent Office Building, the gallery not only serves as a repository of art but also as a monument of American history, contributing significantly to the community's cultural landscape [Data: Entities (526, 549); Relationships (483, 490)].\n\n## Old Patent Office Building's historical significance\n\nThe Old Patent Office Building is a key architectural and historical entity, housing both the Smithsonian American Art Museum and the National Portrait Gallery. Its historical significance and role as a venue for these major institutions amplify its impact within the community, making it a cornerstone of both architectural heritage and cultural education [Data: Entities (549); Relationships (489, 490)].\n\n## Renwick Gallery's contribution to contemporary arts\n\nThe Renwick Gallery, as a branch of the Smithsonian American Art Museum located near the White House, specializes in contemporary craft and decorative arts. Its proximity to a significant political landmark and its focus on modern artistic expressions make it an influential entity within the community, bridging historical arts with contemporary cultural dynamics [Data: Entities (527); Relationships (488, 432)].\n\n## Integration within the Smithsonian Institution\n\nAll entities discussed are integral parts of the Smithsonian Institution, which is a testament to their importance and interconnectedness. The Smithsonian Institution's overarching governance and support enable these entities to thrive and contribute to the cultural and educational landscape of Washington, D.C., thereby enhancing their collective impact [Data: Relationships (484, 483)].",
#    'rank': 7.5,
#    'index_name': 'index_wiki',
#    'index_id': '101'}],
#  'entities': [],
#  'relationships': [],
#  'claims': [],
#  'sources': []}

# %% [markdown]
# ### Local Query
#
# Local search queries are best suited for narrow-focused questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?)

# %%
# %%time


def local_search(index_name: str | list[str], query: str) -> requests.Response:
    """Run a local query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/local"
    request = {"index_name": index_name, "query": query}
    return requests.post(url, json=request, headers=headers)


# perform a local query
local_response = local_search(
    index_name=index_name, query="Summarize the main topics found in this data"
)
local_response_data = parse_query_response(local_response, return_context_data=True)
local_response_data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File <timed exec>:12
#
# Cell In[17], line 9, in parse_query_response(response, return_context_data)
#       5 """
#       6 Print response['result'] value and return context data.
#       7 """
#       8 if response.ok:
# ----> 9     print(json.loads(response.text)["result"])
#      10     if return_context_data:
#      11         return json.loads(response.text)["context_data"]
#
# File /usr/local/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/local/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/local/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
